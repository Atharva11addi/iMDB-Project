# %% [markdown]
# ATHARVA BHATIA DST 10224

# %%
# Import Pandas and NumPy

import numpy as np
import pandas as pd

#pip install db-sqlite3
#SQLite in general is a server-less database that you can use within almost all programming languages including Python.
import sqlite3

# %% [markdown]
# We import the sqlite3 module and then create a connection object which will connect us to the database and will let us execute the SQL statements.
#
# sqlite3.connect(Database)
#
# __cursor()__ - we can use the cursor object to call the execute() method to execute any SQL queries.
#
# __STEPS:__
# To query data in an SQLite database from Python, you use these steps:
#
# - First, establish a connection to the SQLite database by creating a Connection object.
# - Next, create a Cursor object using the cursor method of the Connection object.
# - Then, execute a SELECT statement.
# - After that, call the fetchall() method of the cursor object to fetch the data.
# - Finally, loop the cursor and process each row individually.

# %%
db = 'movies.sqlite'


conn = sqlite3.connect(db)
cur = conn.cursor()

# %% [markdown]
# ## QUESTIONS
# ### Question 1: Can you get all data about movies?

# %%
db = 'movies.sqlite'


conn = sqlite3.connect(db)
cur = conn.cursor()
cur.execute('SELECT * FROM movies')
#use the cursor object to call the execute() method to execute any SQL queries.
movies = cur.fetchall()

#movies -> if u print movies , all the data shown in list manner, can't understanadble

#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.

movies = pd.DataFrame(movies, columns = ['id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Movies data :',movies.shape)
print('\n\n\n')
movies.head(10)
#Displays first 3 rows in the table
# Out:
# Shape of Movies data : (4773, 13)
#       id                            original_title     budget  popularity  \
# 0  43597                                    Avatar  237000000         150
# 1  43598  Pirates of the Caribbean: At World's End  300000000         139
# 2  43599                                   Spectre  245000000         107
# 3  43600                     The Dark Knight Rises  250000000         112
# 4  43601                               John Carter  260000000          43
# 5  43602                              Spider-Man 3  258000000         115
# 6  43603                                   Tangled  260000000          48
# 7  43604                   Avengers: Age of Ultron  280000000         134
# 8  43605    Harry Potter and the Half-Blood Prince  250000000          98
# 9  43606        Batman v Superman: Dawn of Justice  250000000         155
#
#   release_date     revenue                                     title  \
# ...

# %% [markdown]
# ANALYSIS:
# IN this question, we aim to find all the data about movies present in the table. This is achieved using 'select' command.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4773 entries, 0 to 4772
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              4773 non-null   int64
#  1   original_title  4773 non-null   object
#  2   budget          4773 non-null   int64
#  3   popularity      4773 non-null   int64
#  4   release_date    4773 non-null   object
#  5   revenue         4773 non-null   int64
#  6   title           4773 non-null   object
#  7   vote_average    4773 non-null   float64
#  8   vote_count      4773 non-null   int64
#  9   overview        4770 non-null   object
#  10  tagline         3951 non-null   object
#  11  uid             4773 non-null   int64
#  12  director_id     4773 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 484.9+ KB

# %% [markdown]
# ## Question 2: How do you get all data about directors?

# %%
cur.execute('SELECT * FROM directors')
#use the cursor object to call the execute() method to execute any SQL queries.

directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Directors data :',directors.shape)
print('\n\n\n')


directors.head(11)
# Out:
# Shape of Directors data : (2349, 5)
#                  name    id  gender    uid department
# 0       James Cameron  4762       2   2710  Directing
# 1      Gore Verbinski  4763       2   1704  Directing
# 2          Sam Mendes  4764       2     39  Directing
# 3   Christopher Nolan  4765       2    525  Directing
# 4      Andrew Stanton  4766       2      7  Directing
# 5           Sam Raimi  4767       2   7623  Directing
# 6        Byron Howard  4768       2  76595  Directing
# 7         Joss Whedon  4769       2  12891  Directing
# 8         David Yates  4770       2  11343  Directing
# 9         Zack Snyder  4771       2  15217  Directing
# 10       Bryan Singer  4772       2   9032  Directing

# %% [markdown]
# ANALYSIS:
# In this question, we aim to find all the data about directors present in the table. This is achieved using 'select' command.

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2349 non-null   object
#  1   id          2349 non-null   int64
#  2   gender      2349 non-null   int64
#  3   uid         2349 non-null   int64
#  4   department  2349 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 91.9+ KB

# %% [markdown]
# Question 3: Check how many movies are present in iMDB.

# %%
cur.execute('SELECT COUNT(*)FROM movies')
#use the cursor object to call the execute() method to execute any SQL queries.

movies = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


for x in movies:
    print(x)
# Out:
# (4773,)

# %% [markdown]
# ANALYSIS:
# In this question we had to count all the movies in iMDB, we achieved this using 'COUNT' function.

# %% [markdown]
# Note/ Analysis : I had generated virtual table with 3 columns of date, id and movies and I got results that POTC is the most awarded voted movie from Jan 1,2000

# %% [markdown]
# Question 4: Find these 3 directors: James Cameron ; Luc Besson ; John Woo

# %%
cur.execute('SELECT * FROM directors WHERE name = "James Cameron" OR name = "Luc Besson" OR name = "John Woo"')
directors = cur.fetchall()

directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])

directors.head(11)
# Out:
#             name    id  gender    uid department
# 0  James Cameron  4762       2   2710  Directing
# 1       John Woo  4893       2  11401  Directing
# 2     Luc Besson  4949       2     59  Directing

# %% [markdown]
# ANALYSIS:
# In ths question we had to find details about three directors and this was achieved using 'where' clause in 'select' command.

# %% [markdown]
# Question 5: Find all directors with name starting with Steven.

# %%
cur.execute('SELECT name FROM directors WHERE name LIKE "Steven%"')
directors = cur.fetchall()

directors = pd.DataFrame(directors, columns = ['name'])


directors.head(11)
# Out:
#                  name
# 0    Steven Spielberg
# 1   Steven Soderbergh
# 2        Steven Brill
# 3     Steven Zaillian
# 4        Steven Quale
# 5       Steven Seagal
# 6  Steven E. de Souza
# 7    Steven Shainberg
# 8    Steven R. Monroe

# %% [markdown]
# ANALYSIS:
#     In this question we had to find the names of all directors starting with 'Steven' and this was attained using 'LIKE' command in Where clause.

# %% [markdown]
# Question 6: Count female directors.

# %%
cur.execute('SELECT COUNT(*) FROM directors WHERE gender=1')
directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.
for x in directors:
    print(x)
# Out:
# (150,)

# %% [markdown]
# ANALYSIS:
# In this question we had to find the total no. of female directors in the table, this was achieved by Count method.

# %% [markdown]
# Question 7: Find the name of the 10th first women directors?

# %%
cur.execute('SELECT * FROM directors WHERE gender=1 ')
directors = cur.fetchall()
#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.


directors = pd.DataFrame(directors, columns = ['name', 'id', 'gender', 'uid', 'department'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.



directors.head(10)
# Out:
#                   name    id  gender     uid department
# 0       Brenda Chapman  4801       1   59803  Directing
# 1      Lilly Wachowski  4805       1    9339  Directing
# 2  Jennifer Yuh Nelson  4853       1  142312  Directing
# 3      Kathryn Bigelow  4970       1   14392  Directing
# 4         Nancy Meyers  4978       1   17698  Directing
# 5          Jill Culton  4979       1    7881  Directing
# 6           Mimi Leder  4996       1   51984  Directing
# 7         Vicky Jenson  5032       1   12058  Directing
# 8         Betty Thomas  5052       1   31024  Directing
# 9       Angelina Jolie  5086       1   11701  Directing

# %% [markdown]
# ANALYSIS:
# In this question we had to find the name of 10 first female directors in our directors table, this was achieved giving the query as 'gender=1.'

# %% [markdown]
# Question 8: What are the 3 most popular movies?

# %%
cur.execute('SELECT original_title FROM movies ORDER BY popularity DESC')
#use the cursor object to call the execute() method to execute any SQL queries.
movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'original_title'])

movies.head(3)
# Out:
#   original_title
# 0        Minions
# 1   Interstellar
# 2       Deadpool

# %% [markdown]
# ANALYSIS:
# In this question we had to find the 3 most popular movies and it was attained using ORDER BY clause.

# %% [markdown]
# Question 9: What are the 3 most bankable movies?

# %%
cur.execute('SELECT original_title FROM movies ORDER BY revenue DESC')
#use the cursor object to call the execute() method to execute any SQL queries.
movies = cur.fetchall()

#movies -> if u print movies , all the data shown in list manner, can't understanadble

#Note - fetchall() --> fetch all rows for the current query, if no rows avaliable then,it returns an empty list.

movies = pd.DataFrame(movies, columns = [ 'original_title'])
#Creating a dataframe, A dataframe contains rows and columns , It is a Two-dimensional, size-mutable, potentially heterogeneous tabular data.

print('Shape of Movies data :',movies.shape)
print('\n\n\n')
movies.head(3)
# Out:
# Shape of Movies data : (4773, 1)
#   original_title
# 0         Avatar
# 1        Titanic
# 2   The Avengers

# %% [markdown]
# ANALYSIS:
# In this question we had to find the three most bankable movies and it was achieved using ORDER BY clause in descending order.

# %% [markdown]
# Question 10: What is the most awarded average vote since the January 1st, 2000?

# %%
cur.execute('SELECT vote_average FROM movies WHERE release_date > 2000-01-01 ORDER BY vote_count DESC')

movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'vote_average'])

movies.head(1)
# Out:
#    vote_average
# 0           8.1

# %% [markdown]
# ANALYSIS:
# The most awarded vote since January 1st,2000 was executed using 'WHERE' clause and 'ORDER BY' clause. Order by clause had to be applied at vote_count.

# %% [markdown]
# Question 11: Which movie(s) were directed by Brenda Chapman?

# %%
cur.execute('SELECT original_title FROM movies m JOIN directors d ON m.director_id=d.id WHERE name ="Brenda Chapman"')
movies= cur.fetchall()

for x in movies:
    print(x)
# Out:
# ('Brave',)

# %% [markdown]
# ANALYSIS:
# In this question we had to find the movies which were directed by Brenda Chapman and this was achieved by JOINING' the two tables.

# %% [markdown]
# Question 12: Whose director made the most movies?

# %%
cur.execute(' SELECT name,count(name) FROM movies m Join directors d ON m.director_id=d.id group by director_id order by count(name) DESC limit 10')

movies = cur.fetchall()


for x in movies:
    print(x)
# Out:
# ('Steven Spielberg', 27)
# ('Woody Allen', 21)
# ('Clint Eastwood', 20)
# ('Martin Scorsese', 20)
# ('Spike Lee', 16)
# ('Robert Rodriguez', 16)
# ('Ridley Scott', 16)
# ('Renny Harlin', 15)
# ('Steven Soderbergh', 15)
# ('Oliver Stone', 14)

# %% [markdown]
# ANALYSIS:
# In this question we had to find the directors who made the most movies, this was achieved by 'Joining' the two tables and using 'Order By' clause. Count function was also used. A limit of 10 directors was applied so that the output remains short.

# %% [markdown]
# Question 13: Whose director is the most bankable?

# %%
cur.execute('SELECT name,revenue FROM movies m Join directors d ON m.director_id=d.id group by director_id order by revenue DESC limit 10')
movies = cur.fetchall()


for x in movies:
    print(x)
# Out:
# ('James Cameron', 2787965087)
# ('Colin Trevorrow', 1513528810)
# ('James Wan', 1506249360)
# ('Joss Whedon', 1405403694)
# ('Chris Buck', 1274219009)
# ('Shane Black', 1215439994)
# ('Kyle Balda', 1156730962)
# ('Anthony Russo', 1153304495)
# ('Christopher Nolan', 1084939099)
# ('Lee Unkrich', 1066969703)

# %% [markdown]
# ANALYSIS:
# In this question we had to find the directors who mad the most bankable movies, this was achieved by 'Joining' the tables and 'order by' clause. a limit of 10 was also applied.

# %% [markdown]
# ## List out Top 10 highest budget made movies

# %%
cur.execute('SELECT * FROM movies ORDER BY budget DESC')

movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])

movies.head(10)
# Out:
#       id                               original_title     budget  popularity  \
# 0  43614  Pirates of the Caribbean: On Stranger Tides  380000000         135
# 1  43598     Pirates of the Caribbean: At World's End  300000000         139
# 2  43604                      Avengers: Age of Ultron  280000000         134
# 3  43607                             Superman Returns  270000000          57
# 4  43601                                  John Carter  260000000          43
# 5  43603                                      Tangled  260000000          48
# 6  43602                                 Spider-Man 3  258000000         115
# 7  43610                              The Lone Ranger  255000000          49
# 8  43600                        The Dark Knight Rises  250000000         112
# 9  43605       Harry Potter and the Half-Blood Prince  250000000          98
#
#   release_date     revenue                                        title  \
# ...

# %% [markdown]
# ANALYSIS:
# In this we had to perform analysis on the top 10 budget movies present in the table and it was achieved using ORDER BY clause.
# This list contains all the information about top 10 budget movies.
# We can see that Pirates of the Carribean: On Stranger Tides is the most expensive movie made and Harry Potter and the Hlaf Blood Prince is the least expensive.

# %% [markdown]
# List out Top 10 popularity on movies

# %%
cur.execute('SELECT * FROM movies ORDER BY popularity DESC')

movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])

movies.head(10)
# Out:
#       id                                     original_title     budget  \
# 0  44143                                            Minions   74000000
# 1  43692                                       Interstellar  165000000
# 2  44385                                           Deadpool   58000000
# 3  43691                            Guardians of the Galaxy  170000000
# 4  43724                                 Mad Max: Fury Road  150000000
# 5  43625                                     Jurassic World  150000000
# 6  43796  Pirates of the Caribbean: The Curse of the Bla...  140000000
# 7  43679                     Dawn of the Planet of the Apes  170000000
# 8  43797              The Hunger Games: Mockingjay - Part 1  125000000
# 9  43685                                         Big Hero 6  165000000
#
#    popularity release_date     revenue  \
# 0         875   2015-06-17  1156730962
# 1         724   2014-11-05   675120017
# 2         514   2016-02-09   783112979
# ...

# %% [markdown]
# ANALYSIS:
# In this we had to perform analysis on top 10 movies based on the popularity, it was achieved using order by clause. And from this table we can see that Minions is the most popular movie and Big Hero 6 is the last one.

# %% [markdown]
# What are the top 10 Revenue movies

# %%
cur.execute('SELECT * FROM movies ORDER BY Revenue DESC')

movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])

movies.head(10)
# Out:
#       id              original_title     budget  popularity release_date  \
# 0  43597                      Avatar  237000000         150   2009-12-10
# 1  43622                     Titanic  200000000         100   1997-11-18
# 2  43613                The Avengers  220000000         144   2012-04-25
# 3  43625              Jurassic World  150000000         418   2015-06-09
# 4  43641                   Furious 7  190000000         102   2015-04-01
# 5  43604     Avengers: Age of Ultron  280000000         134   2015-04-22
# 6  43721                      Frozen  150000000         165   2013-11-27
# 7  43628                  Iron Man 3  200000000          77   2013-04-18
# 8  44143                     Minions   74000000         875   2015-06-17
# 9  43623  Captain America: Civil War  250000000         198   2016-04-27
#
#       revenue                       title  vote_average  vote_count  \
# 0  2787965087                      Avatar           7.2       11800
# ...

# %% [markdown]
# ANALYSIS:
# In this we had to perform analysis on top 10 movies based on revenue. It was achieved using ORDER BY CLAUSE. From the table we can infer that Avatar is the highest grossing film of all time and Captain America: Civil War is the lowest.

# %% [markdown]
# Display most popular movies with vote_average

# %%
cur.execute('SELECT * FROM movies ORDER BY vote_average DESC')

movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])

movies.head(10)
# Out:
#       id            original_title    budget  popularity release_date  \
# 0  47116          Stiff Upper Lips         0           0   1998-06-12
# 1  47642     Dancer, Texas Pop. 81         0           0   1998-05-01
# 2  47589                 Sardaarji         0           0   2015-06-26
# 3  45983            One Man's Hero         0           0   1999-08-02
# 4  45478  The Shawshank Redemption  25000000         136   1994-09-23
# 5  46567        There Goes My Baby  10500000           0   1994-09-02
# 6  46393     The Prisoner of Zenda         0           4   1937-09-03
# 7  46934             The Godfather   6000000         143   1972-03-14
# 8  44259                Fight Club  63000000         146   1999-10-15
# 9  45415          Schindler's List  22000000         104   1993-11-29
#
#      revenue                     title  vote_average  vote_count  \
# 0          0          Stiff Upper Lips          10.0           1
# ...

# %% [markdown]
# ANALYSIS:
# In this we had to perform analysis based on popularity of vote_average. Attained using ORDER BY Clause.
# From the table we can infer that Stiff Upper Lips and Dancer Texas Pop 81 have the highest vote average of '10' whereas Schindler's List has the lowest vote average of 8.3.

# %% [markdown]
# List out Particular movie for Voting average and votecount

# %%
cur.execute('SELECT * FROM movies ORDER BY vote_average AND vote_count DESC')

movies = cur.fetchall()

movies = pd.DataFrame(movies, columns = [ 'id', 'original_title', 'budget', 'popularity', 'release_date', 'revenue', 'title', 'vote_average', 'vote_count', 'overview', 'tagline', 'uid', 'director_id'])

movies.head(1)
# Out:
#       id original_title     budget  popularity release_date     revenue  \
# 0  43597         Avatar  237000000         150   2009-12-10  2787965087
#
#     title  vote_average  vote_count  \
# 0  Avatar           7.2       11800
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                        tagline    uid  director_id
# 0  Enter the World of Pandora.  19995         4762

# %% [markdown]
# ANALYSIS:
# In this we had to find out the particular movie for voting average as well as the vote count of the movie was highest. It was achieved using ORDER BY Clause. From the table we can infer that Avatar has the highest voting average as well as the highest vote count among all the other movies.

# %% [markdown]
# List out the director names with number of movies and revenue

# %%
cur.execute('SELECT name,revenue,count(original_title) FROM movies m Join directors d ON m.director_id=d.id group by director_id')
movies = cur.fetchall()


for x in movies:
    print(x)
# Out:
# ('James Cameron', 2787965087, 7)
# ('Gore Verbinski', 961000000, 7)
# ('Sam Mendes', 880674609, 7)
# ('Christopher Nolan', 1084939099, 8)
# ('Andrew Stanton', 284139100, 4)
# ('Sam Raimi', 890871626, 11)
# ('Byron Howard', 591794936, 1)
# ('Joss Whedon', 1405403694, 3)
# ('David Yates', 933959197, 3)
# ('Zack Snyder', 873260194, 7)
# ('Bryan Singer', 391081192, 8)
# ('Marc Forster', 586090727, 8)
# ('Andrew Adamson', 419651413, 5)
# ('Rob Marshall', 1045713802, 5)
# ('Barry Sonnenfeld', 624026776, 7)
# ('Peter Jackson', 956019788, 9)
# ('Marc Webb', 752215857, 3)
# ('Ridley Scott', 310669540, 16)
# ('Chris Weitz', 372234864, 6)
# ('Anthony Russo', 1153304495, 4)
# ('Peter Berg', 303025485, 6)
# ('Colin Trevorrow', 1513528810, 2)
# ('Shane Black', 1215439994, 2)
# ('Tim Burton', 1025491110, 14)
# ('Brett Ratner', 459359555, 9)
# ('Dan Scanlon', 743559607, 1)
# ('Michael Bay', 836297228, 12)
# ('Joseph Kosinski', 400062763, 2)
# ('John Lasseter', 559852396, 4)
# ...

# %% [markdown]
# ANALYSIS:
# In this we had to list out the director names with number of movies and revenue and this analysis was performed based on Directing.
# It was achieved by'JOINING' the tables as well as using 'count' function on the Movie names.
# From the table we can conclude that no limit was set on the number of entries.
